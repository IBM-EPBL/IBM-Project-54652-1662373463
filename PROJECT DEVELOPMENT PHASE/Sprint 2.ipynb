# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "code",
      "execution_count": 6,
      "metadata": {
        "id": "WDkJqCsu40Vw"
      },
      "outputs": [],
      "source": [
        "import numpy as np\n",
        "import pandas as pd\n",
        "import matplotlib.pyplot as plt\n",
        "import seaborn as sns"
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "data = pd.read_csv('/content/airports.csv')\n",
        "data.drop([\"id\"], axis=1, inplace=True)\n",
        "data.head()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 409
        },
        "id": "AjPiPaW9-pQ6",
        "outputId": "a302f01f-ef97-43c8-f8c7-e35335c4abc5"
      },
      "execution_count": 7,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "  ident           type                                name  latitude_deg  \\\n",
              "0   00A       heliport                   Total Rf Heliport     40.070801   \n",
              "1  00AA  small_airport                Aero B Ranch Airport     38.704022   \n",
              "2  00AK  small_airport                        Lowell Field     59.947733   \n",
              "3  00AL  small_airport                        Epps Airpark     34.864799   \n",
              "4  00AR         closed  Newport Hospital & Clinic Heliport     35.608700   \n",
              "\n",
              "   longitude_deg  elevation_ft continent iso_country iso_region  municipality  \\\n",
              "0     -74.933601          11.0       NaN          US      US-PA      Bensalem   \n",
              "1    -101.473911        3435.0       NaN          US      US-KS         Leoti   \n",
              "2    -151.692524         450.0       NaN          US      US-AK  Anchor Point   \n",
              "3     -86.770302         820.0       NaN          US      US-AL       Harvest   \n",
              "4     -91.254898         237.0       NaN          US      US-AR       Newport   \n",
              "\n",
              "  scheduled_service gps_code iata_code local_code home_link wikipedia_link  \\\n",
              "0                no      00A       NaN        00A       NaN            NaN   \n",
              "1                no     00AA       NaN       00AA       NaN            NaN   \n",
              "2                no     00AK       NaN       00AK       NaN            NaN   \n",
              "3                no     00AL       NaN       00AL       NaN            NaN   \n",
              "4                no      NaN       NaN        NaN       NaN            NaN   \n",
              "\n",
              "  keywords  \n",
              "0      NaN  \n",
              "1      NaN  \n",
              "2      NaN  \n",
              "3      NaN  \n",
              "4     00AR  "
            ],
            "text/html": [
              "\n",
              "  <div id=\"df-63e41fd2-59d9-4074-9b5d-501479044cb8\">\n",
              "    <div class=\"colab-df-container\">\n",
              "      <div>\n",
              "<style scoped>\n",
              "    .dataframe tbody tr th:only-of-type {\n",
              "        vertical-align: middle;\n",
              "    }\n",
              "\n",
              "    .dataframe tbody tr th {\n",
              "        vertical-align: top;\n",
              "    }\n",
              "\n",
              "    .dataframe thead th {\n",
              "        text-align: right;\n",
              "    }\n",
              "</style>\n",
              "<table border=\"1\" class=\"dataframe\">\n",
              "  <thead>\n",
              "    <tr style=\"text-align: right;\">\n",
              "      <th></th>\n",
              "      <th>ident</th>\n",
              "      <th>type</th>\n",
              "      <th>name</th>\n",
              "      <th>latitude_deg</th>\n",
              "      <th>longitude_deg</th>\n",
              "      <th>elevation_ft</th>\n",
              "      <th>continent</th>\n",
              "      <th>iso_country</th>\n",
              "      <th>iso_region</th>\n",
              "      <th>municipality</th>\n",
              "      <th>scheduled_service</th>\n",
              "      <th>gps_code</th>\n",
              "      <th>iata_code</th>\n",
              "      <th>local_code</th>\n",
              "      <th>home_link</th>\n",
              "      <th>wikipedia_link</th>\n",
              "      <th>keywords</th>\n",
              "    </tr>\n",
              "  </thead>\n",
              "  <tbody>\n",
              "    <tr>\n",
              "      <th>0</th>\n",
              "      <td>00A</td>\n",
              "      <td>heliport</td>\n",
              "      <td>Total Rf Heliport</td>\n",
              "      <td>40.070801</td>\n",
              "      <td>-74.933601</td>\n",
              "      <td>11.0</td>\n",
              "      <td>NaN</td>\n",
              "      <td>US</td>\n",
              "      <td>US-PA</td>\n",
              "      <td>Bensalem</td>\n",
              "      <td>no</td>\n",
              "      <td>00A</td>\n",
              "      <td>NaN</td>\n",
              "      <td>00A</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>1</th>\n",
              "      <td>00AA</td>\n",
              "      <td>small_airport</td>\n",
              "      <td>Aero B Ranch Airport</td>\n",
              "      <td>38.704022</td>\n",
              "      <td>-101.473911</td>\n",
              "      <td>3435.0</td>\n",
              "      <td>NaN</td>\n",
              "      <td>US</td>\n",
              "      <td>US-KS</td>\n",
              "      <td>Leoti</td>\n",
              "      <td>no</td>\n",
              "      <td>00AA</td>\n",
              "      <td>NaN</td>\n",
              "      <td>00AA</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>2</th>\n",
              "      <td>00AK</td>\n",
              "      <td>small_airport</td>\n",
              "      <td>Lowell Field</td>\n",
              "      <td>59.947733</td>\n",
              "      <td>-151.692524</td>\n",
              "      <td>450.0</td>\n",
              "      <td>NaN</td>\n",
              "      <td>US</td>\n",
              "      <td>US-AK</td>\n",
              "      <td>Anchor Point</td>\n",
              "      <td>no</td>\n",
              "      <td>00AK</td>\n",
              "      <td>NaN</td>\n",
              "      <td>00AK</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>3</th>\n",
              "      <td>00AL</td>\n",
              "      <td>small_airport</td>\n",
              "      <td>Epps Airpark</td>\n",
              "      <td>34.864799</td>\n",
              "      <td>-86.770302</td>\n",
              "      <td>820.0</td>\n",
              "      <td>NaN</td>\n",
              "      <td>US</td>\n",
              "      <td>US-AL</td>\n",
              "      <td>Harvest</td>\n",
              "      <td>no</td>\n",
              "      <td>00AL</td>\n",
              "      <td>NaN</td>\n",
              "      <td>00AL</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>4</th>\n",
              "      <td>00AR</td>\n",
              "      <td>closed</td>\n",
              "      <td>Newport Hospital &amp; Clinic Heliport</td>\n",
              "      <td>35.608700</td>\n",
              "      <td>-91.254898</td>\n",
              "      <td>237.0</td>\n",
              "      <td>NaN</td>\n",
              "      <td>US</td>\n",
              "      <td>US-AR</td>\n",
              "      <td>Newport</td>\n",
              "      <td>no</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>00AR</td>\n",
              "    </tr>\n",
              "  </tbody>\n",
              "</table>\n",
              "</div>\n",
              "      <button class=\"colab-df-convert\" onclick=\"convertToInteractive('df-63e41fd2-59d9-4074-9b5d-501479044cb8')\"\n",
              "              title=\"Convert this dataframe to an interactive table.\"\n",
              "              style=\"display:none;\">\n",
              "        \n",
              "  <svg xmlns=\"http://www.w3.org/2000/svg\" height=\"24px\"viewBox=\"0 0 24 24\"\n",
              "       width=\"24px\">\n",
              "    <path d=\"M0 0h24v24H0V0z\" fill=\"none\"/>\n",
              "    <path d=\"M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z\"/><path d=\"M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z\"/>\n",
              "  </svg>\n",
              "      </button>\n",
              "      \n",
              "  <style>\n",
              "    .colab-df-container {\n",
              "      display:flex;\n",
              "      flex-wrap:wrap;\n",
              "      gap: 12px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert {\n",
              "      background-color: #E8F0FE;\n",
              "      border: none;\n",
              "      border-radius: 50%;\n",
              "      cursor: pointer;\n",
              "      display: none;\n",
              "      fill: #1967D2;\n",
              "      height: 32px;\n",
              "      padding: 0 0 0 0;\n",
              "      width: 32px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert:hover {\n",
              "      background-color: #E2EBFA;\n",
              "      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n",
              "      fill: #174EA6;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert {\n",
              "      background-color: #3B4455;\n",
              "      fill: #D2E3FC;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert:hover {\n",
              "      background-color: #434B5C;\n",
              "      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n",
              "      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n",
              "      fill: #FFFFFF;\n",
              "    }\n",
              "  </style>\n",
              "\n",
              "      <script>\n",
              "        const buttonEl =\n",
              "          document.querySelector('#df-63e41fd2-59d9-4074-9b5d-501479044cb8 button.colab-df-convert');\n",
              "        buttonEl.style.display =\n",
              "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
              "\n",
              "        async function convertToInteractive(key) {\n",
              "          const element = document.querySelector('#df-63e41fd2-59d9-4074-9b5d-501479044cb8');\n",
              "          const dataTable =\n",
              "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
              "                                                     [key], {});\n",
              "          if (!dataTable) return;\n",
              "\n",
              "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
              "            '<a target=\"_blank\" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'\n",
              "            + ' to learn more about interactive tables.';\n",
              "          element.innerHTML = '';\n",
              "          dataTable['output_type'] = 'display_data';\n",
              "          await google.colab.output.renderOutput(dataTable, element);\n",
              "          const docLink = document.createElement('div');\n",
              "          docLink.innerHTML = docLinkHtml;\n",
              "          element.appendChild(docLink);\n",
              "        }\n",
              "      </script>\n",
              "    </div>\n",
              "  </div>\n",
              "  "
            ]
          },
          "metadata": {},
          "execution_count": 7
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "data.describe()"
      ],
      "metadata": {
        "id": "pQUjXkVW5aNY",
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 300
        },
        "outputId": "bb77bf17-e1a9-416c-890b-019597991b48"
      },
      "execution_count": 8,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "       latitude_deg  longitude_deg  elevation_ft\n",
              "count  56871.000000   56870.000000  46990.000000\n",
              "mean      26.768878     -32.298946   1259.160992\n",
              "std       26.088108      79.852638   1605.092732\n",
              "min      -90.000000    -179.876999  -1266.000000\n",
              "25%       13.154948     -90.582826    212.000000\n",
              "50%       35.933573     -66.129340    730.000000\n",
              "75%       43.695517      15.141990   1557.750000\n",
              "max       82.750000     179.975700  22000.000000"
            ],
            "text/html": [
              "\n",
              "  <div id=\"df-b5716eae-acaa-4912-b9d5-02d9de06642e\">\n",
              "    <div class=\"colab-df-container\">\n",
              "      <div>\n",
              "<style scoped>\n",
              "    .dataframe tbody tr th:only-of-type {\n",
              "        vertical-align: middle;\n",
              "    }\n",
              "\n",
              "    .dataframe tbody tr th {\n",
              "        vertical-align: top;\n",
              "    }\n",
              "\n",
              "    .dataframe thead th {\n",
              "        text-align: right;\n",
              "    }\n",
              "</style>\n",
              "<table border=\"1\" class=\"dataframe\">\n",
              "  <thead>\n",
              "    <tr style=\"text-align: right;\">\n",
              "      <th></th>\n",
              "      <th>latitude_deg</th>\n",
              "      <th>longitude_deg</th>\n",
              "      <th>elevation_ft</th>\n",
              "    </tr>\n",
              "  </thead>\n",
              "  <tbody>\n",
              "    <tr>\n",
              "      <th>count</th>\n",
              "      <td>56871.000000</td>\n",
              "      <td>56870.000000</td>\n",
              "      <td>46990.000000</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>mean</th>\n",
              "      <td>26.768878</td>\n",
              "      <td>-32.298946</td>\n",
              "      <td>1259.160992</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>std</th>\n",
              "      <td>26.088108</td>\n",
              "      <td>79.852638</td>\n",
              "      <td>1605.092732</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>min</th>\n",
              "      <td>-90.000000</td>\n",
              "      <td>-179.876999</td>\n",
              "      <td>-1266.000000</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>25%</th>\n",
              "      <td>13.154948</td>\n",
              "      <td>-90.582826</td>\n",
              "      <td>212.000000</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>50%</th>\n",
              "      <td>35.933573</td>\n",
              "      <td>-66.129340</td>\n",
              "      <td>730.000000</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>75%</th>\n",
              "      <td>43.695517</td>\n",
              "      <td>15.141990</td>\n",
              "      <td>1557.750000</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>max</th>\n",
              "      <td>82.750000</td>\n",
              "      <td>179.975700</td>\n",
              "      <td>22000.000000</td>\n",
              "    </tr>\n",
              "  </tbody>\n",
              "</table>\n",
              "</div>\n",
              "      <button class=\"colab-df-convert\" onclick=\"convertToInteractive('df-b5716eae-acaa-4912-b9d5-02d9de06642e')\"\n",
              "              title=\"Convert this dataframe to an interactive table.\"\n",
              "              style=\"display:none;\">\n",
              "        \n",
              "  <svg xmlns=\"http://www.w3.org/2000/svg\" height=\"24px\"viewBox=\"0 0 24 24\"\n",
              "       width=\"24px\">\n",
              "    <path d=\"M0 0h24v24H0V0z\" fill=\"none\"/>\n",
              "    <path d=\"M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z\"/><path d=\"M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z\"/>\n",
              "  </svg>\n",
              "      </button>\n",
              "      \n",
              "  <style>\n",
              "    .colab-df-container {\n",
              "      display:flex;\n",
              "      flex-wrap:wrap;\n",
              "      gap: 12px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert {\n",
              "      background-color: #E8F0FE;\n",
              "      border: none;\n",
              "      border-radius: 50%;\n",
              "      cursor: pointer;\n",
              "      display: none;\n",
              "      fill: #1967D2;\n",
              "      height: 32px;\n",
              "      padding: 0 0 0 0;\n",
              "      width: 32px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert:hover {\n",
              "      background-color: #E2EBFA;\n",
              "      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n",
              "      fill: #174EA6;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert {\n",
              "      background-color: #3B4455;\n",
              "      fill: #D2E3FC;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert:hover {\n",
              "      background-color: #434B5C;\n",
              "      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n",
              "      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n",
              "      fill: #FFFFFF;\n",
              "    }\n",
              "  </style>\n",
              "\n",
              "      <script>\n",
              "        const buttonEl =\n",
              "          document.querySelector('#df-b5716eae-acaa-4912-b9d5-02d9de06642e button.colab-df-convert');\n",
              "        buttonEl.style.display =\n",
              "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
              "\n",
              "        async function convertToInteractive(key) {\n",
              "          const element = document.querySelector('#df-b5716eae-acaa-4912-b9d5-02d9de06642e');\n",
              "          const dataTable =\n",
              "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
              "                                                     [key], {});\n",
              "          if (!dataTable) return;\n",
              "\n",
              "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
              "            '<a target=\"_blank\" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'\n",
              "            + ' to learn more about interactive tables.';\n",
              "          element.innerHTML = '';\n",
              "          dataTable['output_type'] = 'display_data';\n",
              "          await google.colab.output.renderOutput(dataTable, element);\n",
              "          const docLink = document.createElement('div');\n",
              "          docLink.innerHTML = docLinkHtml;\n",
              "          element.appendChild(docLink);\n",
              "        }\n",
              "      </script>\n",
              "    </div>\n",
              "  </div>\n",
              "  "
            ]
          },
          "metadata": {},
          "execution_count": 8
        }
      ]
    },
    {
      "cell_type": "markdown",
      "source": [
        "Handling missing values"
      ],
      "metadata": {
        "id": "AiLPtCYu5c8b"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "data.info()"
      ],
      "metadata": {
        "id": "XD568xxa5bgX",
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "outputId": "a29fedb5-c3f0-4038-c7be-1b770486fdb1"
      },
      "execution_count": 9,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'pandas.core.frame.DataFrame'>\n",
            "RangeIndex: 56871 entries, 0 to 56870\n",
            "Data columns (total 17 columns):\n",
            " #   Column             Non-Null Count  Dtype  \n",
            "---  ------             --------------  -----  \n",
            " 0   ident              56870 non-null  object \n",
            " 1   type               56871 non-null  object \n",
            " 2   name               56871 non-null  object \n",
            " 3   latitude_deg       56871 non-null  float64\n",
            " 4   longitude_deg      56870 non-null  float64\n",
            " 5   elevation_ft       46990 non-null  float64\n",
            " 6   continent          30244 non-null  object \n",
            " 7   iso_country        56613 non-null  object \n",
            " 8   iso_region         56870 non-null  object \n",
            " 9   municipality       53021 non-null  object \n",
            " 10  scheduled_service  56870 non-null  object \n",
            " 11  gps_code           37089 non-null  object \n",
            " 12  iata_code          7547 non-null   object \n",
            " 13  local_code         29269 non-null  object \n",
            " 14  home_link          3016 non-null   object \n",
            " 15  wikipedia_link     9028 non-null   object \n",
            " 16  keywords           10945 non-null  object \n",
            "dtypes: float64(3), object(14)\n",
            "memory usage: 7.4+ MB\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "data.isnull().sum() "
      ],
      "metadata": {
        "id": "c-YyA-C-5cmB",
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "outputId": "1ad3fb75-2e6d-4680-f6cc-48918a86156b"
      },
      "execution_count": 10,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "ident                    1\n",
              "type                     0\n",
              "name                     0\n",
              "latitude_deg             0\n",
              "longitude_deg            1\n",
              "elevation_ft          9881\n",
              "continent            26627\n",
              "iso_country            258\n",
              "iso_region               1\n",
              "municipality          3850\n",
              "scheduled_service        1\n",
              "gps_code             19782\n",
              "iata_code            49324\n",
              "local_code           27602\n",
              "home_link            53855\n",
              "wikipedia_link       47843\n",
              "keywords             45926\n",
              "dtype: int64"
            ]
          },
          "metadata": {},
          "execution_count": 10
        }
      ]
    },
    {
      "cell_type": "markdown",
      "source": [
        "Data Visualization"
      ],
      "metadata": {
        "id": "OwvdzZKo5iTJ"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "plt.scatter(data['latitude_deg'],data['longitude_deg'])\n",
        "plt.title('longitude_deg vs latitude_deg')\n",
        "plt.xlabel('latitude_deg')\n",
        "plt.ylabel('longitude_deg')\n",
        "plt.show()"
      ],
      "metadata": {
        "id": "Qyh4V4Ma5h6c",
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 296
        },
        "outputId": "d8dd5d0a-c8e4-4168-d78a-ec82879da770"
      },
      "execution_count": 11,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.scatter(data['latitude_deg'],data['elevation_ft'])\n",
        "plt.title('elevation_ft for latitude_deg')\n",
        "plt.xlabel('latitude_deg')\n",
        "plt.ylabel('elevation_ft')\n",
        "plt.show()"
      ],
      "metadata": {
        "id": "dvQkF9TQ5mWO",
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 296
        },
        "outputId": "9049294d-f3c8-4425-beee-77c55b901381"
      },
      "execution_count": 12,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "data[data.elevation_ft >= 2000].plot(kind='scatter', x='longitude_deg', y='elevation_ft',color=\"BLUE\")\n",
        "plt.xlabel(\"longitude_deg\")\n",
        "plt.ylabel(\"elevation_ft\")\n",
        "plt.title(\"elevation_ft>=2000\")\n",
        "plt.grid(True)\n",
        "plt.show()"
      ],
      "metadata": {
        "id": "y2DAQyky5nsD",
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 296
        },
        "outputId": "fa2e2bbe-fece-4142-9a40-88aba49b0fb8"
      },
      "execution_count": 13,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "data[\"longitude_deg\"].plot(kind = 'hist',bins = 200,figsize = (6,6))\n",
        "plt.title(\"longitude_deg\")\n",
        "plt.xlabel(\"longitude_deg\")\n",
        "plt.ylabel(\"scheduled_service\")\n",
        "plt.show()"
      ],
      "metadata": {
        "id": "17Pi9sd15pO3",
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 405
        },
        "outputId": "86561634-5ab1-4ae5-dd10-491bf24b3684"
      },
      "execution_count": 14,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x432 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "p = np.array([data[\"elevation_ft\"].min(),data[\"elevation_ft\"].mean(),data[\"elevation_ft\"].max()])\n",
        "r = [\"Worst\",\"Average\",\"Best\"]\n",
        "plt.bar(p,r)\n",
        "plt.title(\"elevation_ft\")\n",
        "plt.xlabel(\"Level\")\n",
        "plt.ylabel(\"elevation_ft\")\n",
        "plt.show()"
      ],
      "metadata": {
        "id": "ljRJQx0x5qkD",
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 295
        },
        "outputId": "0c5a4083-42c1-418e-deba-dd2a60cf8f74"
      },
      "execution_count": 15,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "g = np.array([data[\"longitude_deg\"].min(),data[\"longitude_deg\"].mean(),data[\"longitude_deg\"].max()])\n",
        "h = [\"Worst\",\"Average\",\"Best\"]\n",
        "plt.bar(g,h)\n",
        "plt.title(\"longitude_deg\")\n",
        "plt.xlabel(\"Level\")\n",
        "plt.ylabel(\"longitude_deg\")\n",
        "plt.show()"
      ],
      "metadata": {
        "id": "gItdBPTh5sfV",
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 295
        },
        "outputId": "ce4e292e-4bf5-4568-fc12-dcb42d88e2c5"
      },
      "execution_count": 16,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "plt.figure(figsize=(10, 10))\n",
        "sns.heatmap(data.corr(), annot=True, linewidths=0.05, fmt= '.2f',cmap=\"magma\")\n",
        "plt.show()"
      ],
      "metadata": {
        "id": "LjmPJWst5t0J",
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 596
        },
        "outputId": "69250394-c147-4c02-ab23-6e1b08671fc1"
      },
      "execution_count": 17,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 720x720 with 2 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(data.shape)\n",
        "n = len(pd.unique(data['name']))\n",
        "d=len(pd.unique(data['type']))\n",
        "print(\"name\",n,\"type\",d)\n",
        "data['scheduled_service'].value_counts()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "fD1NoLtgaMlc",
        "outputId": "fa75f503-22d0-4088-946f-622678d93e71"
      },
      "execution_count": 19,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "(56871, 17)\n",
            "name 53999 type 7\n"
          ]
        },
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "no     53678\n",
              "yes     3192\n",
              "Name: scheduled_service, dtype: int64"
            ]
          },
          "metadata": {},
          "execution_count": 19
        }
      ]
    }
  ]
}
# Out:
# {'nbformat': 4,
#  'nbformat_minor': 0,
#  'metadata': {'colab': {'provenance': []},
#   'kernelspec': {'name': 'python3', 'display_name': 'Python 3'},
#   'language_info': {'name': 'python'}},
#  'cells': [{'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'id': 'WDkJqCsu40Vw'},
#    'outputs': [],
#    'source': ['import numpy as np\n',
#     'import pandas as pd\n',
#     'import matplotlib.pyplot as plt\n',
#     'import seaborn as sns']},
#   {'cell_type': 'code',
#    'source': ["data = pd.read_csv('/content/airports.csv')\n",
#     'data.drop(["id"], axis=1, inplace=True)\n',
#     'data.head()'],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 409},
#     'id': 'AjPiPaW9-pQ6',
#     'outputId': 'a302f01f-ef97-43c8-f8c7-e35335c4abc5'},
#    'execution_count': 7,
#    'outputs': [{'output_type': 'execute_result',
#      'data': {'text/plain': ['  ident           type                                name  latitude_deg  \\\n',
# ...
